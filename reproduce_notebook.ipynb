# %% [markdown]
# # Learning Theory project:
# **Paper:** Being Friends Instead of Adversaries: Deep Networks Learn from Data Simplifed by Other Networks
#
# Here are our **group members**:
# - Thanh Gia Hieu KHUONG
#
# - Alex-Răzvan ISPAS
#
# - Diego Andrés TORRES GUARIN
#
# - Benedictus Kent RACHMAT
#
# - Shah Fahad HOSSAIN

# %%
# !pip install -q sentence_transformers wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 25.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 29.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.9 MB/s eta 0:00:00

# %% [markdown]
# # Download and preprocess data

# %%
# !git clone https://github.com/sailab-code/friendly-training
# Out:
# Cloning into 'friendly-training'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 37 (delta 4), reused 2 (delta 0), pack-reused 28
# Receiving objects: 100% (37/37), 16.21 MiB | 9.51 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd friendly-training
# Out:
# /content/friendly-training

# %% [markdown]
# ## MNIST Variations and geometric shapes

# %%
# !./download_larochelle.sh
# Out:
# --2024-02-28 13:30:56--  http://www.iro.umontreal.ca/~lisa/icml2007data/mnist_background_images.zip
# Resolving www.iro.umontreal.ca (www.iro.umontreal.ca)... 132.204.26.36
# Connecting to www.iro.umontreal.ca (www.iro.umontreal.ca)|132.204.26.36|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92013211 (88M) [application/zip]
# Saving to: ‘mnist_background_images.zip’
#
# mnist_background_im 100%[===================>]  87.75M  13.3MB/s    in 8.1s
#
# 2024-02-28 13:31:05 (10.9 MB/s) - ‘mnist_background_images.zip’ saved [92013211/92013211]
#
# Archive:  mnist_background_images.zip
#   inflating: mnist_back_image/mnist_background_images_train.amat
#   inflating: mnist_back_image/mnist_background_images_test.amat
# --2024-02-28 13:31:10--  http://www.iro.umontreal.ca/~lisa/icml2007data/mnist_rotation_back_image_new.zip
# Resolving www.iro.umontreal.ca (www.iro.umontreal.ca)... 132.204.26.36
# ...

# %% [markdown]
# ## Wines

# %%
## Preprocess data (only run once)

# !python data/wines_data_processing.py
# !cp data/wine/*.pt /content/drive/MyDrive/UPSaclay/learning_theory/wine/
# !cp data/wine/*.dat /content/drive/MyDrive/UPSaclay/learning_theory/wine/
# Out:
# modules.json: 100% 229/229 [00:00<00:00, 1.22MB/s]
# config_sentence_transformers.json: 100% 122/122 [00:00<00:00, 632kB/s]
# README.md: 100% 3.78k/3.78k [00:00<00:00, 23.8MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 318kB/s]
# config.json: 100% 718/718 [00:00<00:00, 4.40MB/s]
# pytorch_model.bin: 100% 329M/329M [00:28<00:00, 11.3MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json: 100% 1.32k/1.32k [00:00<00:00, 7.19MB/s]
# vocab.json: 100% 798k/798k [00:00<00:00, 810kB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 618kB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:01<00:00, 1.10MB/s]
# ...

# %%
# Load preprocessed data

# !mkdir -p data/wine
# !cp /content/drive/MyDrive/UPSaclay/learning_theory/wine/*.pt data/wine/
# !cp /content/drive/MyDrive/UPSaclay/learning_theory/wine/*.dat data/wine/

# %% [markdown]
# ## IMDB

# %%
# !./download_imdb.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# aclImdb/train/unsup/44983_0.txt
# aclImdb/train/unsup/44982_0.txt
# aclImdb/train/unsup/44981_0.txt
# aclImdb/train/unsup/44980_0.txt
# aclImdb/train/unsup/44979_0.txt
# aclImdb/train/unsup/44978_0.txt
# aclImdb/train/unsup/44977_0.txt
# aclImdb/train/unsup/44976_0.txt
# aclImdb/train/unsup/44975_0.txt
# aclImdb/train/unsup/44974_0.txt
# aclImdb/train/unsup/44973_0.txt
# aclImdb/train/unsup/44972_0.txt
# aclImdb/train/unsup/44971_0.txt
# aclImdb/train/unsup/44970_0.txt
# aclImdb/train/unsup/44969_0.txt
# aclImdb/train/unsup/44968_0.txt
# aclImdb/train/unsup/44967_0.txt
# aclImdb/train/unsup/44966_0.txt
# aclImdb/train/unsup/44965_0.txt
# aclImdb/train/unsup/44964_0.txt
# aclImdb/train/unsup/44963_0.txt
# aclImdb/train/unsup/44962_0.txt
# aclImdb/train/unsup/44961_0.txt
# aclImdb/train/unsup/44960_0.txt
# aclImdb/train/unsup/44959_0.txt
# aclImdb/train/unsup/44958_0.txt
# aclImdb/train/unsup/44957_0.txt
# ...

# %%
## Preprocess data (only run once)

# !python data/imdb_data_processing.py
# !cp data/reviews/*.pt /content/drive/MyDrive/UPSaclay/learning_theory/reviews/
# !cp data/wine/*.dat /content/drive/MyDrive/UPSaclay/learning_theory/wine/

# %%
# Load preprocessed data

# !mkdir -p data/reviews
# !cp /content/drive/MyDrive/UPSaclay/learning_theory/reviews/*.pt data/reviews/
# !cp /content/drive/MyDrive/UPSaclay/learning_theory/reviews/*.dat data/reviews/

# %% [markdown]
# # Training

# %%
# !python train-neural.py
# Out:
# Total params Namespace(lr_simp=0.0001, lr_clf=0.0001, lr_factor_clf=1.0, ratio_simp=0.25, iterations_simp=1, beta_simp=10.0, acc_thres=None, scaling='quadratic', activation='relu', simplifier='ff', target_conditioning='no', data_augmentation='no', cos_scheduler=None, noisy_labels=0.0, sigmoid_postprocessing='no', arch='ff', optim='adam', weight_decay_clf=1e-08, weight_decay_simp=1e-08, n_deep=None, n_filters_base=None, hidden=[256, 784], dataset='mnist_back_image', run=2, seed=1, epochs=200, batch_size=32, test_batch_size=512, baseline=False)
# I will use 0 workers..
# steps_with_simp 15650
# SimplifierFF(
#   (generator): Sequential(
#     (0): Linear(in_features=784, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=784, bias=True)
#   )
# )
# Net(
#   (fc1): Linear(in_features=784, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
# )
# 100% 313/313 [00:01<00:00, 297.77it/s]
# ...

# %% [markdown]
# ## Digit Recognition

# %%
python train-neural.py --activation=relu --arch=ff --beta_simp=2000 --dataset=mnist_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=64 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=ff --beta_simp=2000 --dataset=mnist_rot_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=64 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=ff --beta_simp=2000 --dataset=mnist_rot --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=64 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=ff --beta_simp=500 --dataset=rectangles_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=128 --ratio_simp=0.85 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=ff --beta_simp=2000 --dataset=convex --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=128 --ratio_simp=0.85 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=mnist_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=96 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=mnist_rot_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=128 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=ff2 --beta_simp=500 --dataset=mnist_rot --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=128 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=rectangles_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=64 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=ff2 --beta_simp=500 --dataset=convex --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=128 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn --beta_simp=500 --dataset=mnist_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=96 --ratio_simp=0.85 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn --beta_simp=2000 --dataset=mnist_rot_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=96 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn --beta_simp=1000 --dataset=mnist_rot --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=96 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn --beta_simp=500 --dataset=rectangles_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=96 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn --beta_simp=2000 --dataset=convex --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=128 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn2 --beta_simp=500 --dataset=mnist_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=64 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn2 --beta_simp=2000 --dataset=mnist_rot_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=64 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn2 --beta_simp=2000 --dataset=mnist_rot --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=128 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn2 --beta_simp=1000 --dataset=rectangles_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=64 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
python train-neural.py --activation=relu --arch=cnn2 --beta_simp=1000 --dataset=convex --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=128 --ratio_simp=0.25 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Valid set: Average loss: 2.7377, Accuracy: 643/2000 (32%)
# Test set: Average loss: 2.7432, Accuracy: 15502/50000 (31%)
# Elapsed time:  6.52
# epoch: 36, loss: 0.1257, acc: 0.96
# 100% 313/313 [00:02<00:00, 114.17it/s]
# 100% 313/313 [00:02<00:00, 111.61it/s]
#
# Valid set: Average loss: 2.7734, Accuracy: 655/2000 (33%)
# Test set: Average loss: 2.7578, Accuracy: 16121/50000 (32%)
# Elapsed time:  6.32
# epoch: 37, loss: 0.1078, acc: 0.97
# 100% 313/313 [00:02<00:00, 113.87it/s]
# 100% 313/313 [00:02<00:00, 110.27it/s]
#
# Valid set: Average loss: 2.6055, Accuracy: 662/2000 (33%)
# Test set: Average loss: 2.5564, Accuracy: 16800/50000 (34%)
# Elapsed time:  6.49
# epoch: 38, loss: 0.7065, acc: 0.78
# 100% 313/313 [00:02<00:00, 115.71it/s]
# 100% 313/313 [00:02<00:00, 108.63it/s]
#
# Valid set: Average loss: 2.7828, Accuracy: 667/2000 (33%)
# Test set: Average loss: 2.7333, Accuracy: 16913/50000 (34%)
# Elapsed time:  6.37
# ...

# %%
# !python train-neural.py --activation=relu --arch=ff --beta_simp=2000 --dataset=mnist_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=64 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff --beta_simp=2000 --dataset=mnist_rot_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=64 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff --beta_simp=2000 --dataset=mnist_rot --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=64 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff --beta_simp=500 --dataset=rectangles_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=128 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff --beta_simp=2000 --dataset=convex --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=128 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch: 5, loss: 2.1676, acc: 0.25
# 100% 313/313 [00:00<00:00, 487.55it/s]
#
# Valid set: Average loss: 2.1351, Accuracy: 519/2000 (26%)
# Test set: Average loss: 2.1279, Accuracy: 13303/50000 (27%)
# Elapsed time:  1.16
# epoch: 6, loss: 2.1310, acc: 0.26
# 100% 313/313 [00:00<00:00, 484.42it/s]
#
# Valid set: Average loss: 2.1109, Accuracy: 529/2000 (26%)
# Test set: Average loss: 2.1016, Accuracy: 12987/50000 (26%)
# Elapsed time:  1.17
# epoch: 7, loss: 2.0968, acc: 0.27
# 100% 313/313 [00:00<00:00, 486.76it/s]
#
# Valid set: Average loss: 2.0659, Accuracy: 560/2000 (28%)
# Test set: Average loss: 2.0643, Accuracy: 14088/50000 (28%)
# Elapsed time:  1.27
# epoch: 8, loss: 2.0636, acc: 0.27
# 100% 313/313 [00:00<00:00, 488.61it/s]
#
# Valid set: Average loss: 2.0487, Accuracy: 563/2000 (28%)
# Test set: Average loss: 2.0387, Accuracy: 14374/50000 (29%)
# Elapsed time:  1.17
# epoch: 9, loss: 2.0323, acc: 0.28
# ...

# %%
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=mnist_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=96 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=mnist_rot_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=128 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=500 --dataset=mnist_rot --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=128 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=rectangles_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=64 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=500 --dataset=convex --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=128 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# Out:
# Streaming output truncated to the last 5000 lines.
# Valid set: Average loss: 2.5449, Accuracy: 820/2000 (41%)
# Test set: Average loss: 2.4934, Accuracy: 21249/50000 (42%)
# Elapsed time:  1.88
# epoch: 10, loss: 0.2505, acc: 0.92
# 100% 313/313 [00:01<00:00, 253.22it/s]
#
# Valid set: Average loss: 2.5015, Accuracy: 855/2000 (43%)
# Test set: Average loss: 2.4685, Accuracy: 21237/50000 (42%)
# Elapsed time:  1.88
# epoch: 11, loss: 0.2250, acc: 0.93
# 100% 313/313 [00:01<00:00, 250.05it/s]
#
# Valid set: Average loss: 2.6221, Accuracy: 837/2000 (42%)
# Test set: Average loss: 2.4792, Accuracy: 21811/50000 (44%)
# Elapsed time:  1.91
# epoch: 12, loss: 0.2281, acc: 0.93
# 100% 313/313 [00:01<00:00, 249.16it/s]
#
# Valid set: Average loss: 2.6887, Accuracy: 837/2000 (42%)
# Test set: Average loss: 2.5981, Accuracy: 21270/50000 (43%)
# Elapsed time:  2.01
# epoch: 13, loss: 0.1988, acc: 0.93
# 100% 313/313 [00:01<00:00, 254.37it/s]
#
# ...

# %%
# !python train-neural.py --activation=relu --arch=cnn --beta_simp=500 --dataset=mnist_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=96 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=cnn --beta_simp=2000 --dataset=mnist_rot_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=96 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=cnn --beta_simp=1000 --dataset=mnist_rot --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=96 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=cnn --beta_simp=500 --dataset=rectangles_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=96 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=cnn --beta_simp=2000 --dataset=convex --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=128 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch: 7, loss: 1.4640, acc: 0.49
# 100% 313/313 [00:00<00:00, 345.87it/s]
#
# Valid set: Average loss: 1.3602, Accuracy: 1089/2000 (54%)
# Test set: Average loss: 1.3453, Accuracy: 27487/50000 (55%)
# Elapsed time:  1.68
# epoch: 8, loss: 1.4025, acc: 0.51
# 100% 313/313 [00:00<00:00, 351.17it/s]
#
# Valid set: Average loss: 1.3201, Accuracy: 1118/2000 (56%)
# Test set: Average loss: 1.3038, Accuracy: 27962/50000 (56%)
# Elapsed time:  1.56
# epoch: 9, loss: 1.3508, acc: 0.53
# 100% 313/313 [00:00<00:00, 348.88it/s]
#
# Valid set: Average loss: 1.2746, Accuracy: 1149/2000 (57%)
# Test set: Average loss: 1.2644, Accuracy: 28730/50000 (57%)
# Elapsed time:  1.55
# epoch: 10, loss: 1.2997, acc: 0.55
# 100% 313/313 [00:00<00:00, 345.81it/s]
#
# Valid set: Average loss: 1.2418, Accuracy: 1158/2000 (58%)
# Test set: Average loss: 1.2297, Accuracy: 29116/50000 (58%)
# Elapsed time:  1.59
# epoch: 11, loss: 1.2481, acc: 0.57
# ...

# %%
# !python train-neural.py --activation=relu --arch=cnn2 --beta_simp=500 --dataset=mnist_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --n_deep=4 --n_filters_base=64 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=cnn2 --beta_simp=2000 --dataset=mnist_rot_back_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=64 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=cnn2 --beta_simp=2000 --dataset=mnist_rot --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=128 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=cnn2 --beta_simp=1000 --dataset=rectangles_image --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --n_deep=4 --n_filters_base=64 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=cnn2 --beta_simp=1000 --dataset=convex --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0005 --n_deep=4 --n_filters_base=128 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch: 8, loss: 1.2421, acc: 0.57
# 100% 313/313 [00:01<00:00, 292.21it/s]
#
# Valid set: Average loss: 1.1294, Accuracy: 1250/2000 (62%)
# Test set: Average loss: 1.1164, Accuracy: 31478/50000 (63%)
# Elapsed time:  1.84
# epoch: 9, loss: 1.2050, acc: 0.59
# 100% 313/313 [00:01<00:00, 294.31it/s]
#
# Valid set: Average loss: 1.0908, Accuracy: 1281/2000 (64%)
# Test set: Average loss: 1.0853, Accuracy: 31915/50000 (64%)
# Elapsed time:  1.84
# epoch: 10, loss: 1.1526, acc: 0.61
# 100% 313/313 [00:01<00:00, 291.00it/s]
#
# Valid set: Average loss: 1.0648, Accuracy: 1300/2000 (65%)
# Test set: Average loss: 1.0600, Accuracy: 32472/50000 (65%)
# Elapsed time:  1.89
# epoch: 11, loss: 1.1141, acc: 0.63
# 100% 313/313 [00:01<00:00, 288.99it/s]
#
# Valid set: Average loss: 1.0310, Accuracy: 1336/2000 (67%)
# Test set: Average loss: 1.0252, Accuracy: 33210/50000 (66%)
# Elapsed time:  1.85
# epoch: 12, loss: 1.0832, acc: 0.63
# ...

# %%
# !python train-delta.py --arch=ff --conf_thres=0.98 --dataset=mnist_back_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=ff --conf_thres=0.98 --dataset=mnist_rot_back_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=ff --conf_thres=0.98 --dataset=mnist_rot --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=ff --conf_thres=0.98 --dataset=rectangles_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=ff --conf_thres=0.98 --dataset=convex --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# Out:
# Total params Namespace(ratio_simp=0.5, iterations_simp=120, step_simp=0.1, conf_thres=0.98, scaling='quadratic', arch='ff', data_augmentation=None, noisy_labels=0.0, dataset='mnist_back_image', load_classifier=None, cos_scheduler=None, run=2, seed=1, epochs=200, batch_size=32, test_batch_size=512, lr=0.0001, lr_factor=None, weight_decay=0.0001, init='kaiming', optim='adam', baseline=False, output_simplifier='linear')
# I will use 0 workers..
# Net(
#   (fc1): Linear(in_features=784, out_features=10, bias=True)
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
# )
# 100% 313/313 [01:33<00:00,  3.33it/s]
# Elapsed time:  93.86522626876831
# epoch: 1, loss: 2.2367, acc: 0.23
#
# Valid set: Average loss: 2.2219, Accuracy: 578/2000 (29%)
# Test set: Average loss: 2.2196, Accuracy: 13632/50000 (27%)
# Logging corrected images..
# 100% 313/313 [01:43<00:00,  3.04it/s]
# Elapsed time:  103.05107021331787
# epoch: 2, loss: 2.1195, acc: 0.38
#
# ...

# %%
# !python train-delta.py --arch=ff2 --conf_thres=0.98 --dataset=mnist_back_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=ff2 --conf_thres=0.98 --dataset=mnist_rot_back_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=ff2 --conf_thres=0.98 --dataset=mnist_rot --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=ff2 --conf_thres=0.98 --dataset=rectangles_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=ff2 --conf_thres=0.98 --dataset=convex --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1

# %%
# !python train-delta.py --arch=cnn --conf_thres=0.98 --dataset=mnist_back_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=cnn --conf_thres=0.98 --dataset=mnist_rot_back_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=cnn --conf_thres=0.98 --dataset=mnist_rot --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=cnn --conf_thres=0.98 --dataset=rectangles_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=cnn --conf_thres=0.98 --dataset=convex --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1

# %%
# !python train-delta.py --arch=cnn2 --conf_thres=0.98 --dataset=mnist_back_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=cnn2 --conf_thres=0.98 --dataset=mnist_rot_back_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=cnn2 --conf_thres=0.98 --dataset=mnist_rot --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=cnn2 --conf_thres=0.98 --dataset=rectangles_image --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1
# !python train-delta.py --arch=cnn2 --conf_thres=0.98 --dataset=convex --iterations_simp=120 --ratio_simp=0.5 --scaling=quadratic --step_simp=0.1

# %% [markdown]
# # Image classification

# %%
### CNN-B on CIFAR10
## BASELINE (ratio_simp = 0.0)
python train-neural.py --activation=relu --arch=cnn2 --beta_simp=1000 --dataset=cifar10 --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --epochs 200 --weight_decay_clf=0.0001 --weight_decay_simp=0.0001

## FT
python train-delta.py --arch=cnn2 --conf_thres=0.98 --dataset=cifar10 --epochs=200 --iterations_simp=10 --ratio_simp=0.25 --scaling=quadratic --step_simp=0.01

## NFT
python train-neural.py --activation=relu --arch=cnn2 --beta_simp=500 --dataset=cifar10 --epochs=200 --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.85 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_clf=0.0001 --weight_decay_simp=0.0001

### RESNET on CIFAR10-N10
## BASELINE (ratio_simp = 0.0)
python train-neural.py --activation=relu --arch=resnet --beta_simp=2000 --dataset=cifar10-n10 --epochs=250 --iterations_simp=1 --lr_simp=0.0005 --ratio_simp=0 --run=4 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_simp=0.0001

## FT
python train-delta.py --arch=resnet --conf_thres=0.85 --dataset=cifar10-n10 --epochs=250 --iterations_simp=10 --ratio_simp=0.1 --scaling=quadratic --step_simp=10

## NFT
python train-neural.py --activation=relu --arch=resnet --beta_simp=1000 --dataset=cifar10-n10 --epochs=250 --iterations_simp=1 --lr_factor_clf=0.1 --lr_simp=0.0005 --n_deep=2 --n_filters_base=96 --noisy_labels=0.1 --ratio_simp=0.7 --run=3 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=unet --target_conditioning=no --weight_decay_simp=0.0001
# Out:
# Streaming output truncated to the last 5000 lines.
# Test set: Average loss: 1.1065, Accuracy: 6917/10000 (69%)
# Logging corrected images..
# 100% 1250/1250 [00:11<00:00, 111.23it/s]
# Elapsed time:  11.23973798751831
# epoch: 75, loss: 0.4167, acc: 0.84
#
# Valid set: Average loss: 1.0584, Accuracy: 6929/10000 (69%)
# Test set: Average loss: 1.1010, Accuracy: 6937/10000 (69%)
# Logging corrected images..
# 100% 1250/1250 [00:10<00:00, 116.46it/s]
# Elapsed time:  10.734545946121216
# epoch: 76, loss: 0.4189, acc: 0.84
#
# Valid set: Average loss: 1.0599, Accuracy: 6902/10000 (69%)
# Test set: Average loss: 1.1010, Accuracy: 6920/10000 (69%)
# Logging corrected images..
# 100% 1250/1250 [00:10<00:00, 116.19it/s]
# Elapsed time:  10.75995135307312
# epoch: 77, loss: 0.4161, acc: 0.85
#
# Valid set: Average loss: 1.0709, Accuracy: 6902/10000 (69%)
# Test set: Average loss: 1.1075, Accuracy: 6951/10000 (70%)
# Logging corrected images..
# 100% 1250/1250 [00:10<00:00, 115.80it/s]
# ...

# %% [markdown]
# ## Sentiment analysis

# %%
## BASELINES (ratio_simp = 0.0)
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=imdb50k --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=no --epochs 30 --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=winedr --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=no --epochs 30 --weight_decay_clf=0.0001 --weight_decay_simp=0.0001

## FT
# !python train-delta.py --arch=ff2 --conf_thres=0.9 --dataset=imdb50k --epochs=30 --iterations_simp=120 --ratio_simp=0.25 --scaling=quadratic --step_simp=10
# !python train-delta.py --arch=ff2 --conf_thres=0.98 --dataset=winedr --epochs=30 --iterations_simp=80 --ratio_simp=0.5 --scaling=quadratic --step_simp=10

## NFT
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=imdb50k --epochs=30 --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=500 --dataset=winedr --epochs=30 --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# Out:
# Total params Namespace(lr_simp=1e-05, lr_clf=0.0001, lr_factor_clf=1.0, ratio_simp=0.0, iterations_simp=0, beta_simp=1000.0, acc_thres=None, scaling='quadratic', activation='relu', simplifier='ff', target_conditioning='no', data_augmentation='no', cos_scheduler=None, noisy_labels=0.0, sigmoid_postprocessing='no', arch='ff2', optim='adam', weight_decay_clf=0.0001, weight_decay_simp=0.0001, n_deep=None, n_filters_base=None, hidden=[256, 20002], dataset='imdb50k', run=2, seed=1, epochs=30, batch_size=32, test_batch_size=512, baseline=True)
# I will use 0 workers..
# steps_with_simp 0
# SimplifierFF(
#   (generator): Sequential(
#     (0): Linear(in_features=20002, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=20002, bias=True)
#   )
# )
# Net2(
#   (fc1): Linear(in_features=20002, out_features=2500, bias=True)
#   (fc2): Linear(in_features=2500, out_features=2000, bias=True)
# ...

# %%
## BASELINES (ratio_simp = 0.0)
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=imdb50k --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=no --epochs 30 --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=winedr --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=no --epochs 30 --weight_decay_clf=0.0001 --weight_decay_simp=0.0001

## FT
# !python train-delta.py --arch=ff2 --conf_thres=0.9 --dataset=imdb50k --epochs=30 --iterations_simp=120 --ratio_simp=0.25 --scaling=quadratic --step_simp=10
# !python train-delta.py --arch=ff2 --conf_thres=0.98 --dataset=winedr --epochs=30 --iterations_simp=80 --ratio_simp=0.5 --scaling=quadratic --step_simp=10

## NFT
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=imdb50k --epochs=30 --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=500 --dataset=winedr --epochs=30 --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# Out:
# Total params Namespace(lr_simp=1e-05, lr_clf=0.0001, lr_factor_clf=1.0, ratio_simp=0.0, iterations_simp=0, beta_simp=1000.0, acc_thres=None, scaling='quadratic', activation='relu', simplifier='ff', target_conditioning='no', data_augmentation='no', cos_scheduler=None, noisy_labels=0.0, sigmoid_postprocessing='no', arch='ff2', optim='adam', weight_decay_clf=0.0001, weight_decay_simp=0.0001, n_deep=None, n_filters_base=None, hidden=[256, 20002], dataset='imdb50k', run=2, seed=1, epochs=30, batch_size=32, test_batch_size=512, baseline=True)
# I will use 0 workers..
# steps_with_simp 0
# SimplifierFF(
#   (generator): Sequential(
#     (0): Linear(in_features=20002, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=20002, bias=True)
#   )
# )
# Net2(
#   (fc1): Linear(in_features=20002, out_features=2500, bias=True)
#   (fc2): Linear(in_features=2500, out_features=2000, bias=True)
# ...

# %%
## BASELINES (ratio_simp = 0.0)
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=imdb50k --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=no --epochs 30 --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=winedr --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.0 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=no --epochs 30 --weight_decay_clf=0.0001 --weight_decay_simp=0.0001

## FT
# !python train-delta.py --arch=ff2 --conf_thres=0.9 --dataset=imdb50k --epochs=30 --iterations_simp=120 --ratio_simp=0.25 --scaling=quadratic --step_simp=10
# !python train-delta.py --arch=ff2 --conf_thres=0.98 --dataset=winedr --epochs=30 --iterations_simp=80 --ratio_simp=0.5 --scaling=quadratic --step_simp=10

## NFT
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=1000 --dataset=imdb50k --epochs=30 --iterations_simp=1 --lr_clf=0.0001 --lr_simp=0.0001 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# !python train-neural.py --activation=relu --arch=ff2 --beta_simp=500 --dataset=winedr --epochs=30 --iterations_simp=1 --lr_clf=0.0001 --lr_simp=1e-05 --ratio_simp=0.5 --scaling=quadratic --sigmoid_postprocessing=no --simplifier=ff --target_conditioning=yes --weight_decay_clf=0.0001 --weight_decay_simp=0.0001
# Out:
# Total params Namespace(lr_simp=1e-05, lr_clf=0.0001, lr_factor_clf=1.0, ratio_simp=0.0, iterations_simp=0, beta_simp=1000.0, acc_thres=None, scaling='quadratic', activation='relu', simplifier='ff', target_conditioning='no', data_augmentation='no', cos_scheduler=None, noisy_labels=0.0, sigmoid_postprocessing='no', arch='ff2', optim='adam', weight_decay_clf=0.0001, weight_decay_simp=0.0001, n_deep=None, n_filters_base=None, hidden=[256, 20002], dataset='imdb50k', run=2, seed=1, epochs=30, batch_size=32, test_batch_size=512, baseline=True)
# I will use 0 workers..
# steps_with_simp 0
# SimplifierFF(
#   (generator): Sequential(
#     (0): Linear(in_features=20002, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=20002, bias=True)
#   )
# )
# Net2(
#   (fc1): Linear(in_features=20002, out_features=2500, bias=True)
#   (fc2): Linear(in_features=2500, out_features=2000, bias=True)
# ...
